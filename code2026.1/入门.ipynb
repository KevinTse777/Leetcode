# %%
class Solution:
    def addDigits(self, num: int) -> int:
        
        while num>9:
            sum = 0
            while num:
               sum += num % 10 
               num //= 10
            num = sum
        return num
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(greenmangoisgod)
#
# NameError: name 'greenmangoisgod' is not defined

# %%
class Solution:
    def subtractProductAndSum(self, n: int) -> int:
        sum = 0
        csum = 1
        while n :
            sum += n %10
            csum *= n % 10
            n //= 10
        return csum - sum

# %%
class Solution:
    def isPowerOfTwo(self, n: int) -> bool:
        while n>1:
            n /= 2
        return n == 1
    
sol = Solution()    
sol.isPowerOfTwo(16)
# Out:
# True

# %%
class Solution:
    def isUgly(self, n: int) -> bool:
        if n <= 0:
            return False
        while n % 3 == 0 :
            n //= 3
        while n % 5 == 0 :
            n //=5
        return n & (n-1) == 0

# %%
class Solution:
    def shuffle(self, nums: List[int], n: int) -> List[int]:
        newnums = [0]*2*n
        for i in range (n):
            newnums[2*i] = nums[i]
            newnums[2*i+1] = nums[n+i]
        return newnums

sol = Solution()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 class Solution:
#       2     def shuffle(self, nums: List[int], n: int) -> List[int]:
#       3         newnums:List[int] = []*2*n
#
# Cell In[6], line 2, in Solution()
#       1 class Solution:
# ----> 2     def shuffle(self, nums: List[int], n: int) -> List[int]:
#       3         newnums:List[int] = []*2*n
#       4         for i in range (n):
#
# NameError: name 'List' is not defined

# %%
class Solution:
    def transpose(self, matrix: List[List[int]]) -> List[List[int]]:
        m = len(matrix)
        n = len(matrix[0])
        newmatrix = [[0]*m for _ in range(n)]
        for i ,rows in enumerate(matrix):
           for j ,x in enumerate(rows):
               newmatrix[j][i]=x
               
        return newmatrix

#矩阵建立 获取索引和值 矩阵长度读取

# %%
class Solution:
    def maxScore(self, s: str) -> int:
        score = s.count('1')
        ans = 0
        for c in s[:-1]:
            score += 1 if c=='0' else -1
            ans = max(ans,score)
        return ans       
    
#字符串的遍历

# %%
class Solution:
    def vowelStrings(self, words: List[str], left: int, right: int) -> int:
        count = 0
        for word in words [left:right+1]:
            if word[0] in 'aeiou' and word[-1] in 'aeiou':
                count += 1
        return count

# %%
class Solution:
    def peakIndexInMountainArray(self, arr: List[int]) -> int:
        left , right = 0 , len(arr) - 2
        while left + 1 < right:
            mid = (left + right) // 2
            if arr[mid] > arr [mid+1]:
                right = mid
            else :
                left = mid
        return right
        
#二分法
